# %%
import folium

# %%
from pyproj import crs
import pandas as pd

from folium.plugins import HeatMap

from folium.plugins import MarkerCluster

from folium import IFrame, FeatureGroup, LayerControl

from folium.plugins import GroupedLayerControl

# %%
# Create a Map instance
m = folium.Map(location=[48.8639368381152, 2.349781581911858], zoom_start=6, control_scale=True)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa47d4200438f8951980da91b6f47ddb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa47d4200438f8951980da91b6f47ddb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa47d4200438f8951980da91b6f47ddb = L.map(
#                 &quot;map_fa47d4200438f8951980da91b6f47ddb&quot;,
#                 {
#                     center: [48.8639368381152, 2.349781581911858],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_fa47d4200438f8951980da91b6f47ddb);
#
#
#
#
#
#             var tile_layer_894da4a2dceb91adc06b8ebae603a4e3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fa47d4200438f8951980da91b6f47ddb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Création de la carte interactive

# %%
Tree = pd.read_excel('data/20230717_Lacuzon Arbre_data.xlsx')

# %%
Tree[Tree["Génération"]==1]
# Out:
#    Unnamed: 0       ID  Sosa  Génération          Name Genre BIRTH_PLACE  \
# 0           0  @I0024@     1           1  Benoit PROST     M         NaN
#
#     BIRTH_DATE  MARRIAGE_PLACE  MARRIAGE_DATE  ... BIRTH_YEAR Réel ou Projeté  \
# 0  11 MAY 1990             NaN            NaN  ...                          R
#
#   BIRTH_YEAR DEATH_YEAR  Réel ou Projeté DEATH_YEAR Age  \
# 0       1990                           P       2050 NaN
#
#    Lieu normé Réel ou Projeté    Lieux_normé  Département      long        lat
# 0                           P  Paris, France         75.0  2.352222  48.856614
#
# [1 rows x 24 columns]

# %%
# Following this example: https://github.com/python-visualization/folium/blob/master/examples/MarkerCluster.ipynb


# Create a list of coordinate pairs
locations_list = list(zip(Tree[Tree["Génération"]==11]["lat"], Tree[Tree["Génération"]==11]["long"]))

# %%
# Create a Map instance
m = folium.Map(location=[48.8639368381152, 2.349781581911858], zoom_start=6, control_scale=True)

# %%
# Create a folium marker cluster
marker_cluster = MarkerCluster(locations_list)

# Add marker cluster to map
marker_cluster.add_to(m)

# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a55bcc9ce1d7c583fdeaf10628b042ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a55bcc9ce1d7c583fdeaf10628b042ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a55bcc9ce1d7c583fdeaf10628b042ff = L.map(
#                 &quot;map_a55bcc9ce1d7c583fdeaf10628b042ff&quot;,
#                 {
#                     center: [48.8639368381152, 2.349781581911858],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a55bcc9ce1d7c583fdeaf10628b042ff);
#
#
#
#
#
#             var tile_layer_b39af08c8689b02b89a6c98aedabc1c2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a55bcc9ce1d7c583fdeaf10628b042ff);
#
#
#             var marker_cluster_ea7aa11584975cf57116790759c1ea1c = L.markerClusterGroup(
#                 {}
#             );
#             map_a55bcc9ce1d7c583fdeaf10628b042ff.addLayer(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_7a96156c08538c507f36df678f6449b1 = L.marker(
#                 [47.10631799999999, 5.893047],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_16054907f901ede83a782271b93893d9 = L.marker(
#                 [47.103127, 5.883235],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_5062b0a3f0e299745a5708c0e96754b8 = L.marker(
#                 [47.10631799999999, 5.893047],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_764d4c07596cc8588214de911907de1a = L.marker(
#                 [47.10631799999999, 5.893047],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_c624dd936977eb96a43a5dca7f25246a = L.marker(
#                 [47.10631799999999, 5.893047],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_daebeff10031e75d6fb6a8a7469dfad2 = L.marker(
#                 [47.10631799999999, 5.893047],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_0e92f80b32717b0b7f7112b3e0e5884a = L.marker(
#                 [47.10631799999999, 5.893047],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_8788ee425225da16a9b5d3c0d825eec5 = L.marker(
#                 [47.10631799999999, 5.893047],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_df36c753dca3a5eadc8f98e2a1271b91 = L.marker(
#                 [47.72058, 6.6308365],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_0e41c0ab6e44a3632ae7d8b2de910134 = L.marker(
#                 [47.71226799999999, 6.579642],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_eb2917eda444d0d37fa04247712136a1 = L.marker(
#                 [47.7702699, 6.611732],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_d4ff3e5025c89b982ae191ada6cd8f51 = L.marker(
#                 [47.815313, 6.683637999999999],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_c0f8aebf529f244b1104df5519f569ff = L.marker(
#                 [47.72058, 6.6308365],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_a19ce2ff77c446ce2c49cac9253d1fed = L.marker(
#                 [47.720535, 6.732355],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_f0ff4e1213d75768e93e6f2906efdf8c = L.marker(
#                 [47.72058, 6.6308365],
#                 {}
#             ).addTo(marker_cluster_ea7aa11584975cf57116790759c1ea1c);
#
#
#             var marker_229aad74ca34cf0834e0125e4e284942 = L.marker(

# %%
# Create a Map instance
m = folium.Map(location=[48.8639368381152, 2.349781581911858], zoom_start=6, control_scale=True)

# %%
marker_cluster_G8 = MarkerCluster(name="G8").add_to(m)
Gene = 8


for index, location_info in Tree[Tree["Génération"]==Gene].iterrows():
    location = [location_info["lat"], location_info["long"]]
  
    folium.Marker(
        location=location,
        popup=location_info["Name"],
    ).add_to(marker_cluster_G8)

    

LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bc69a7335ccfa98b063b5c11f266cf2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bc69a7335ccfa98b063b5c11f266cf2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bc69a7335ccfa98b063b5c11f266cf2 = L.map(
#                 &quot;map_3bc69a7335ccfa98b063b5c11f266cf2&quot;,
#                 {
#                     center: [48.8639368381152, 2.349781581911858],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3bc69a7335ccfa98b063b5c11f266cf2);
#
#
#
#
#
#             var tile_layer_cfca4e9d7aa8da3d173e934a46172c1f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3bc69a7335ccfa98b063b5c11f266cf2);
#
#
#             var marker_cluster_bb9f169f0f847976c025aed055c7b16e = L.markerClusterGroup(
#                 {}
#             );
#             map_3bc69a7335ccfa98b063b5c11f266cf2.addLayer(marker_cluster_bb9f169f0f847976c025aed055c7b16e);
#
#
#             var marker_866dacf3c6412727697325fef6e4aadd = L.marker(
#                 [46.50271900000001, 5.505693],
#                 {}
#             ).addTo(marker_cluster_bb9f169f0f847976c025aed055c7b16e);
#
#
#         var popup_1f6f73d09860aed215a4f538f7f43a74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c2f2c22363f4bdef1d41abbf0625169 = $(`&lt;div id=&quot;html_4c2f2c22363f4bdef1d41abbf0625169&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pierre Humbert PROST ROMAND&lt;/div&gt;`)[0];
#                 popup_1f6f73d09860aed215a4f538f7f43a74.setContent(html_4c2f2c22363f4bdef1d41abbf0625169);
#
#
#
#         marker_866dacf3c6412727697325fef6e4aadd.bindPopup(popup_1f6f73d09860aed215a4f538f7f43a74)
#         ;
#
#
#
#
#             var marker_d3cd14247449980d33d9a4c955ba1b12 = L.marker(
#                 [46.528372, 5.55919],
#                 {}
#             ).addTo(marker_cluster_bb9f169f0f847976c025aed055c7b16e);
#
#
#         var popup_c8eb8244599aad7e809ad70d851b7fbe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d57858b4231e93b33b9e7d9c246beb53 = $(`&lt;div id=&quot;html_d57858b4231e93b33b9e7d9c246beb53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marie Thérèse CORCELLE&lt;/div&gt;`)[0];
#                 popup_c8eb8244599aad7e809ad70d851b7fbe.setContent(html_d57858b4231e93b33b9e7d9c246beb53);
#
#
#
#         marker_d3cd14247449980d33d9a4c955ba1b12.bindPopup(popup_c8eb8244599aad7e809ad70d851b7fbe)
#         ;
#
#
#
#
#             var marker_4129e568a5655f1727bf388abd691cdd = L.marker(
#                 [47.0961904, 5.4879961],
#                 {}
#             ).addTo(marker_cluster_bb9f169f0f847976c025aed055c7b16e);
#
#
#         var popup_ec0958a5ab661ce7efe7249eb0a6f690 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b0886fbdbc5b1350e3f746d384b3280 = $(`&lt;div id=&quot;html_6b0886fbdbc5b1350e3f746d384b3280&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Etienne GELLION&lt;/div&gt;`)[0];
#                 popup_ec0958a5ab661ce7efe7249eb0a6f690.setContent(html_6b0886fbdbc5b1350e3f746d384b3280);
#
#
#
#         marker_4129e568a5655f1727bf388abd691cdd.bindPopup(popup_ec0958a5ab661ce7efe7249eb0a6f690)
#         ;
#
#
#
#
#             var marker_0c0fc0bf105bd81bba0a5fa75b013cd1 = L.marker(
#                 [47.0961904, 5.4879961],
#                 {}
#             ).addTo(marker_cluster_bb9f169f0f847976c025aed055c7b16e);
#
#
#         var popup_2c7f218ed660de1d76354503a2cbbcad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2cf24ed27d0c1357da6839d2327403ab = $(`&lt;div id=&quot;html_2cf24ed27d0c1357da6839d2327403ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Claudine CARRETTE&lt;/div&gt;`)[0];
#                 popup_2c7f218ed660de1d76354503a2cbbcad.setContent(html_2cf24ed27d0c1357da6839d2327403ab);
#
#
#
#         marker_0c0fc0bf105bd81bba0a5fa75b013cd1.bindPopup(popup_2c7f218ed660de1d76354503a2cbbcad)
#         ;
#
#
#
#
#             var marker_85fbd10204a8ca78829277d8fdb4cd98 = L

# %%
# Create a Map instance
m = folium.Map(location=[48.8639368381152, 2.349781581911858], zoom_start=6, control_scale=True)

# %%
GenerationList = Tree["Génération"].drop_duplicates().sort_values().values

GenerationLayer = []

for i in range(len(GenerationList)):
    Gene = GenerationList[i]
    globals()[f"marker_cluster_G{Gene}"] = MarkerCluster(name=f"G{Gene}", overlay=True).add_to(m)
   
    GenerationLayer.append(globals()[f"marker_cluster_G{Gene}"])
    for index, location_info in Tree[Tree["Génération"]==Gene].iterrows():
        location = [location_info["lat"], location_info["long"]]
  
        folium.Marker(
            location=location,
            popup=location_info["Name"],
        ).add_to(globals()[f"marker_cluster_G{Gene}"])
    
LayerControl().add_to(m)

GroupedLayerControl(
    groups={'Génération': GenerationLayer},
    exclusive_groups=True,
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_daa710cac95cfa861c3c7242a9f18699 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_daa710cac95cfa861c3c7242a9f18699&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_daa710cac95cfa861c3c7242a9f18699 = L.map(
#                 &quot;map_daa710cac95cfa861c3c7242a9f18699&quot;,
#                 {
#                     center: [48.8639368381152, 2.349781581911858],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_daa710cac95cfa861c3c7242a9f18699);
#
#
#
#
#
#             var tile_layer_15fbe33e834bf11d4e0bcc80b113add3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_daa710cac95cfa861c3c7242a9f18699);
#
#
#             var marker_cluster_848d0c7efb6748403424ffcedb6f8f06 = L.markerClusterGroup(
#                 {}
#             );
#             map_daa710cac95cfa861c3c7242a9f18699.addLayer(marker_cluster_848d0c7efb6748403424ffcedb6f8f06);
#
#
#             var marker_e46184b9a08d8dde96a6cc3c6b1f0a30 = L.marker(
#                 [48.856614, 2.3522219],
#                 {}
#             ).addTo(marker_cluster_848d0c7efb6748403424ffcedb6f8f06);
#
#
#         var popup_dc562d213f265259d1212a4f123ce913 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7334aedcb7e7cc67bb9e4d5e9ceebc0 = $(`&lt;div id=&quot;html_f7334aedcb7e7cc67bb9e4d5e9ceebc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Benoit PROST&lt;/div&gt;`)[0];
#                 popup_dc562d213f265259d1212a4f123ce913.setContent(html_f7334aedcb7e7cc67bb9e4d5e9ceebc0);
#
#
#
#         marker_e46184b9a08d8dde96a6cc3c6b1f0a30.bindPopup(popup_dc562d213f265259d1212a4f123ce913)
#         ;
#
#
#
#
#             var marker_cluster_df594beb26be14417affa9beed3ca887 = L.markerClusterGroup(
#                 {}
#             );
#             map_daa710cac95cfa861c3c7242a9f18699.addLayer(marker_cluster_df594beb26be14417affa9beed3ca887);
#
#
#             var marker_44c6e995bf07d2ae2713112a8b00801e = L.marker(
#                 [48.7305769, 2.447488],
#                 {}
#             ).addTo(marker_cluster_df594beb26be14417affa9beed3ca887);
#
#
#         var popup_87246151175174863020d73c69a91b89 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9219e29b773f7371f821c33f73d4ee29 = $(`&lt;div id=&quot;html_9219e29b773f7371f821c33f73d4ee29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pierre-Louis PROST&lt;/div&gt;`)[0];
#                 popup_87246151175174863020d73c69a91b89.setContent(html_9219e29b773f7371f821c33f73d4ee29);
#
#
#
#         marker_44c6e995bf07d2ae2713112a8b00801e.bindPopup(popup_87246151175174863020d73c69a91b89)
#         ;
#
#
#
#
#             var marker_dcf11965c2bf5b7498abd19e953bf591 = L.marker(
#                 [48.856614, 2.3522219],
#                 {}
#             ).addTo(marker_cluster_df594beb26be14417affa9beed3ca887);
#
#
#         var popup_1823110c3b6bf53f2f743e716258b3da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_301c28367d747d8cf5c1e789d556772e = $(`&lt;div id=&quot;html_301c28367d747d8cf5c1e789d556772e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Juliette SALESSES&lt;/div&gt;`)[0];
#                 popup_1823110c3b6bf53f2f743e716258b3da.setContent(html_301c28367d747d8cf5c1e789d556772e);
#
#
#
#         marker_dcf11965c2bf5b7498abd19e953bf591.bindPopup(popup_1823110c3b6bf53f2f743e716258b3da)
#         ;
#
#
#
#
#             var marker_cluster_9e65aaf7c91a615d0198539c3a26d77c = L.markerClusterGroup(
#                 {}
#             );
#             map_daa710cac95cfa861c3c7242a9f18699.addLayer(marker_cluster_9e65aaf7c91a615d0198539c3a26d77c);
#
#
#             var marker_e6a5834afe62139e2b1e5ec21f860843 = L.marker(

# %%
outfp = "GeneMap.html"
m.save(outfp)

# %% [markdown]
# # Parser du Gedcom

# %% [markdown]
# ***Objectif*** : Travailler un gedcom afin de créer un dataframe panda exploitable

# %%
from ged4py import GedcomReader
from ged4py.date import DateValueVisitor

import pandas as pd

# %%
# Path to your `.ged` file
path = 'data/20230713_Prost Lacuzon-Export_all.ged'

# Initialize the parser
parser = GedcomReader(path, encoding="utf-8")

# %%
# Fonction ajout individu

def ParseIndividuGeneration(ID, Sosa, Genera):
    for i, indi in enumerate(parser.records0("INDI")):
        if indi.xref_id == ID:

            IndividuGénération['ID'].append(indi.xref_id)
            IndividuGénération['Sosa'].append(Sosa)
            IndividuGénération['Génération'].append(Genera)
            IndividuGénération['Name'].append(indi.name.format())
            IndividuGénération['Genre'].append(indi.sub_tag_value("SEX"))
            IndividuGénération['BIRTH_PLACE'].append(indi.sub_tag_value("BIRT/PLAC"))
            IndividuGénération['BIRTH_DATE'].append(indi.sub_tag_value("BIRT/DATE"))
            IndividuGénération['MARRIAGE_PLACE'].append(indi.sub_tag_value("MARR/PLAC"))
            IndividuGénération['MARRIAGE_DATE'].append(indi.sub_tag_value("MARR/DATE"))
            IndividuGénération['DEATH_PLACE'].append(indi.sub_tag_value("DEAT/PLAC"))
            IndividuGénération['DEATH_DATE'].append(indi.sub_tag_value("DEAT/DATE"))        


            if indi.father != None:
                IndividuGénération['Father'].append(indi.father.xref_id) 
            else: IndividuGénération['Father'].append(None)

            if indi.mother != None:
                IndividuGénération['Mother'].append(indi.mother.xref_id)
            else: IndividuGénération['Mother'].append(None)
            break

# %%
# Dictionnaire des individus par génération
IndividuGénération = {'ID':[], 'Sosa':[], "Génération" :[] ,"Name" :[], "Genre" :[], "BIRTH_PLACE" :[], "BIRTH_DATE" :[], "MARRIAGE_PLACE" :[], "MARRIAGE_DATE" :[], "DEATH_PLACE" :[], "DEATH_DATE" :[], "Father" :[], "Mother" :[]}

# %%
# Initialisation du sujet 0

ID = '@I0024@'
Sosa = 1
Genera = 1
            
ParseIndividuGeneration(ID, 1, 1)

# %%
DfIndividuGénération = pd.DataFrame.from_dict(IndividuGénération)

# %%
#Boucle itération génération
Genera = 1
Gen = True

while Gen == True:
    Gen = False
    
    #Rajout père
    for index, DfIndividu_info in DfIndividuGénération[DfIndividuGénération['Génération']==Genera].iterrows():
        if DfIndividu_info['Father'] != None:
            ID = DfIndividu_info['Father']
            Sosa = DfIndividu_info['Sosa'] *2
            GeneraInd = Genera + 1

            ParseIndividuGeneration(ID, Sosa, GeneraInd)
            Gen = True

    #Rajout mère
    for index, DfIndividu_info in DfIndividuGénération[DfIndividuGénération['Génération']==Genera].iterrows():
        if DfIndividu_info['Mother'] != None:
            ID = DfIndividu_info['Mother']
            Sosa = DfIndividu_info['Sosa'] *2 + 1
            GeneraInd = Genera + 1

            ParseIndividuGeneration(ID, Sosa, GeneraInd)
            Gen = True
    
    DfIndividuGénération = pd.DataFrame.from_dict(IndividuGénération)
    Genera += 1

# %%
#Suppression des doublons
DfIndividuGénération= DfIndividuGénération.drop_duplicates(subset=['ID'])

# %%
DfIndividuGénération.to_excel("Lacuzon Arbre.xlsx")

# %% [markdown]
# # Geolocalisation

# %%
from geopy.geocoders import GoogleV3

import requests, json

# %%
# Opening JSON file
f = open("Param/param.json")

# returns JSON object as 
# a dictionary
param = json.load(f)

# %%
# Création Geocoder Google
locator = GoogleV3(api_key=param['GooglePlateform_API']['api_key'])

# %%
dFLieu = pd.read_excel('Data/Lieu Genealogie.xlsx')

# %%
Lieu_Info = {'Lieu':[], 'location':[], 'long':[], 'lat':[]}

for index, DfLieu_info in dFLieu.iterrows():
    Lieu_Info['Lieu'].append(DfLieu_info.values[0])
    location = locator.geocode(DfLieu_info.values[0])
    
    if location == None:
        Lieu_Info['location'].append(None)
        Lieu_Info['long'].append(None)
        Lieu_Info['lat'].append(None)      
    else:
        Lieu_Info['location'].append(location)
        Lieu_Info['long'].append(location.longitude)
        Lieu_Info['lat'].append(location.latitude)

# %%
DfLieu_Info = pd.DataFrame.from_dict(Lieu_Info)

# %%
DfLieu_Info.to_excel("LieuGeoCode.xlsx")
